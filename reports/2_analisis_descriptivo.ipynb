# %% [markdown]
# # Análisis descriptivo

# %% [markdown]
# ## Importar librerias

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# Importar widgets interactivos para Jupyter Notebook
import ipywidgets as widgets

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importar funciones especializadas

# %%
# %run '../utils/analisis-descriptivo-univariado.ipynb'
# %run '../utils/analisis-descriptivo-bivariado.ipynb'

# %% [markdown]
# ## Análisis

# %%
df = pd.read_csv('../database/clean/tetuan-pc.csv')
df.head()
# Out:
#               datetime   temp  humi     ws    gdf     df           pc
# 0  2017-01-01 00:00:00  6.559  73.8  0.083  0.051  0.119  70425.53544
# 1  2017-01-01 00:10:00  6.414  74.5  0.083  0.070  0.085  69320.84387
# 2  2017-01-01 00:20:00  6.313  74.5  0.080  0.062  0.100  67803.22193
# 3  2017-01-01 00:30:00  6.121  75.0  0.083  0.091  0.096  65489.23209
# 4  2017-01-01 00:40:00  5.921  75.7  0.081  0.048  0.085  63650.44627

# %%
df.describe()
# Out:
#                temp          humi            ws           gdf            df  \
# count  52416.000000  52416.000000  52416.000000  52416.000000  52416.000000
# mean      18.810024     68.259518      1.959489    182.696614     75.028022
# std        5.815476     15.551177      2.348862    264.400960    124.210949
# min        3.247000     11.340000      0.050000      0.004000      0.011000
# 25%       14.410000     58.310000      0.078000      0.062000      0.122000
# 50%       18.780000     69.860000      0.086000      5.035500      4.456000
# 75%       22.890000     81.400000      4.915000    319.600000    101.000000
# max       40.010000     94.800000      6.483000   1163.000000    936.000000
#
#                   pc
# count   52416.000000
# mean    71222.885864
# std     17143.138964
# min     36785.039739
# 25%     56499.074640
# 50%     69788.790940
# 75%     83749.172310
# max    134208.145950

# %% [markdown]
# ### Analisis descriptivo univariado

# %%
univariate_analysis(df)
# Out:
# Análisis univariado para la columna 'temp':
# ----------------------------------------
# Estadísticas descriptivas:
# count    52416.000000
# mean        18.810024
# std          5.815476
# min          3.247000
# 25%         14.410000
# 50%         18.780000
# 75%         22.890000
# max         40.010000
# Name: temp, dtype: float64
# Análisis univariado para la columna 'humi':
# ----------------------------------------
# Estadísticas descriptivas:
# count    52416.000000
# mean        68.259518
# std         15.551177
# min         11.340000
# 25%         58.310000
# 50%         69.860000
# 75%         81.400000
# max         94.800000
# Name: humi, dtype: float64
# Análisis univariado para la columna 'ws':
# ----------------------------------------
# Estadísticas descriptivas:
# count    52416.000000
# mean         1.959489
# std          2.348862
# min          0.050000
# 25%          0.078000
# 50%          0.086000
# 75%          4.915000
# max          6.483000
# ...

# %% [markdown]
# ### Analisis de correlación

# %%
df.columns
# Out:
# Index(['datetime', 'temp', 'humi', 'ws', 'gdf', 'df', 'pc'], dtype='object')

# %%
df_1 = df[['temp', 'humi', 'ws', 'gdf', 'df', 'pc']]
df_corr = df_1.corr()
df_corr['pc'].sort_values(ascending=False)
# Out:
# pc      1.000000
# temp    0.488238
# ws      0.221706
# gdf     0.150368
# df      0.032068
# humi   -0.299059
# Name: pc, dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.pairplot(df_1, corner=True)
plt.show()
